# %% [markdown]
# Imports

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn import linear_model
from sklearn import metrics
import statistics
import copy
import math
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.api import ExponentialSmoothing, SimpleExpSmoothing, Holt
import seaborn as sns
import gplearn

# %% [markdown]
# Dataset

# %%
data = pd.read_csv(r"C:\Users\thewa\OneDrive\Documents\MTF 2022-2023\dm_export_20131201_20221201.csv")
{'High Plains', 'Midwest', 'Northeast', 'South', 'Southeast', 'West'}

hpdata = data[data["Region"] == "High Plains"].reset_index(drop=True)
mwdata = data[data["Region"] == "Midwest"].reset_index(drop=True)
nedata = data[data["Region"] == "Northeast"].reset_index(drop=True)
shdata = data[data["Region"] == "South"].reset_index(drop=True)
sedata = data[data["Region"] == "Southeast"].reset_index(drop=True)
wtdata = data[data["Region"] == "West"].reset_index(drop=True)

fig = make_subplots(rows=6, cols=1, subplot_titles=list(set(data["Region"])))

fig.add_trace(go.Scatter(x=[i for i in range(len(hpdata))], y=hpdata, marker = dict(color = "Blue")), row = 1, col = 1)
fig.add_trace(go.Scatter(x=[i for i in range(len(mwdata))], y=mwdata, marker = dict(color = "Blue")), row = 2, col = 1)
fig.add_trace(go.Scatter(x=[i for i in range(len(nedata))], y=nedata, marker = dict(color = "Blue")), row = 3, col = 1)
fig.add_trace(go.Scatter(x=[i for i in range(len(shdata))], y=shdata, marker = dict(color = "Blue")), row = 4, col = 1)
fig.add_trace(go.Scatter(x=[i for i in range(len(sedata))], y=sedata, marker = dict(color = "Blue")), row = 5, col = 1)
fig.add_trace(go.Scatter(x=[i for i in range(len(wtdata))], y=wtdata, marker = dict(color = "Blue")), row = 6, col = 1)

fig.update_layout(height=2000, width=800)

fig.show()
hpdata
# Out:
#       MapDate       Region   None     D0     D1     D2     D3    D4  \
# 0    20221129  High Plains   8.25  91.75  75.23  44.07  21.97  8.36
# 1    20221122  High Plains   6.86  93.14  75.87  44.39  21.97  8.36
# 2    20221115  High Plains   6.99  93.01  75.71  43.98  21.74  8.33
# 3    20221108  High Plains   6.16  93.84  76.11  46.54  21.79  7.97
# 4    20221101  High Plains   6.16  93.84  76.17  45.63  20.50  7.93
# ..        ...          ...    ...    ...    ...    ...    ...   ...
# 466  20131224  High Plains  45.79  54.21  20.60  12.28   2.60  0.30
# 467  20131217  High Plains  44.81  55.19  20.96  12.01   2.05  0.30
# 468  20131210  High Plains  44.81  55.19  19.31  11.90   2.05  0.30
# 469  20131203  High Plains  44.58  55.42  19.29  11.71   2.05  0.30
# 470  20131126  High Plains  44.58  55.42  19.29  11.71   2.05  0.30
#
#      ValidStart    ValidEnd  StatisticFormatID
# 0    2022-11-29  2022-12-05                  1
# 1    2022-11-22  2022-11-28                  1
# ...
